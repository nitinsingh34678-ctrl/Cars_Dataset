# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,root_mean_squared_error

# %%
data = pd.DataFrame({
    'hours':[1,2,3,4,5],
    'marks':[2,4,5,4,5]
})
x = data[['hours']]
y=data['marks']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size =0.2,random_state=0)

# %%
model =LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_predict = model.predict(X_test)
new_prediction = model.predict([[6]])
mse = mean_squared_error(Y_test,y_predict)
rmse = root_mean_squared_error(Y_test,y_predict)
r = r2_score(Y_test,y_predict)
# Out:
# C:\Users\bs594\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\bs594\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\metrics\_regression.py:1288: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %%
print("Predict value (test):",y_predict)
print("Actual values:",Y_test)
print("Mean Squared Error:",mse)
print("Root Mean Squared Error:",rmse)
print("R2 score",r)
Accuracy = r*100
print("Accuracy",Accuracy)
# Out:
# Predict value (test): [3.75]
# Actual values: 2    5
# Name: marks, dtype: int64
# Mean Squared Error: 1.5625
# Root Mean Squared Error: 1.25
# R2 score nan
# Accuracy nan

# %%
plt.scatter(x,y,color ='red',label = 'Actual Data')
plt.plot(x,model.predict(x),label= 'Regression Line')
plt.scatter(4,new_prediction,color ='green',s=20,label='Prediction')
plt.legend()
plt.show()
